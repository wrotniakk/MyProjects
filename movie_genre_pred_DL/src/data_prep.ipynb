# %%
import pandas as pd
import numpy as np

# %%
# mount the drive
from google.colab import drive
drive.mount('/content/drive')

# change directory
# %cd drive/MyDrive/Final Project
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Final Project

# %%
movies = pd.read_csv("data/movies_metadata.csv")
# Out:
# <ipython-input-4-f8e68357cbad>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv("data/movies_metadata.csv")

# %%
movies.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
#
# ...

# %%
movies = movies[["genres","overview","title"]]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    45466 non-null  object
#  1   overview  44512 non-null  object
#  2   title     45460 non-null  object
# dtypes: object(3)
# memory usage: 1.0+ MB

# %%
movies.head()
# Out:
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                          title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %%
from ast import literal_eval

# %%
def gender_mining(row):

    row = literal_eval(row)

    genres = []
    for i in row:
        genres.append(i["name"])

    return str(genres)

# %%
movies["genre_list"] = movies["genres"].apply(gender_mining)

# %%
movies.index=movies.title.values

# %%
movies = movies[["genre_list","overview"]]
movies.dropna(inplace=True)
movies = movies[movies["genre_list"]!="[]"]
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42327 entries, Toy Story to Betrayal
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   genre_list  42327 non-null  object
#  1   overview    42327 non-null  object
# dtypes: object(2)
# memory usage: 992.0+ KB
# <ipython-input-13-922480a67e91>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)

# %%
movies.head()
# Out:
#                                                      genre_list  \
# Toy Story                     ['Animation', 'Comedy', 'Family']
# Jumanji                      ['Adventure', 'Fantasy', 'Family']
# Grumpier Old Men                          ['Romance', 'Comedy']
# Waiting to Exhale                ['Comedy', 'Drama', 'Romance']
# Father of the Bride Part II                          ['Comedy']
#
#                                                                       overview
# Toy Story                    Led by Woody, Andy's toys live happily in his ...
# Jumanji                      When siblings Judy and Peter discover an encha...
# Grumpier Old Men             A family wedding reignites the ancient feud be...
# Waiting to Exhale            Cheated on, mistreated and stepped on, the wom...
# Father of the Bride Part II  Just when George Banks has recovered from his ...

# %% [markdown]
# ## Narrowing down to only couple of most distinguishable genres

# %%
genres = ['Fantasy','Horror','Romance','Action','Family']

# %%
def filter(genre_list):

  gens = literal_eval(genre_list)

  return set(gens).issubset(set(genres))

# %%
movies["mask"] = movies["genre_list"].apply(filter)

# %%
movies.head()

# %%
movies_narrowed = movies[movies["mask"]]
movies_narrowed.head()
# Out:
#                                                             genre_list  \
# Mortal Kombat                                    ['Action', 'Fantasy']
# The Neverending Story III: Escape from Fantasia            ['Fantasy']
# Interview with the Vampire                       ['Horror', 'Romance']
# Beyond Bedlam                                               ['Horror']
# Wolf                                                       ['Fantasy']
#
#                                                                                           overview  \
# Mortal Kombat                                    For nine generations an evil sorcerer has been...
# The Neverending Story III: Escape from Fantasia  A young boy must restore order when a group of...
# Interview with the Vampire                       A vampire relates his epic life story of love,...
# Beyond Bedlam                                    An experiment gone awry places a neurologist (...
# ...

# %%
movies_narrowed = movies_narrowed[["genre_list","overview"]]

# %%
movies_narrowed.to_csv("data/movies_genre&overview.csv")
